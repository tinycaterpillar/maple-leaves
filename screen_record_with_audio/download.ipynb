# %% [markdown]
# ### Directory
# work_directory/
# ├─ chromedriver
# ├─ screen_record.ipynb
# https://ascii-tree-generator.com/

# %% [markdown]
# https://velog.io/@syiee/Chrome-Web-Driver-%EC%B5%9C%EC%8B%A0-%EB%B2%84%EC%A0%84-%EC%84%A4%EC%B9%98-%EB%B0%A9%EB%B2%95-119

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import argparse
from subprocess import call

# %% [markdown]
# ### For debug

# %%
import pyautogui
import time
import winsound as sd

def beepsound():
    fr = 2000    # range : 37 ~ 32767
    du = 200     # 1000 ms ==1second
    sd.Beep(fr, du) # winsound.Beep(frequency, duration)

time.sleep(2)
x1, y1 = pyautogui.position()
beepsound()
time.sleep(2)
x2, y2 = pyautogui.position()
beepsound()

print(f'args.offset_x = {x1}')
print(f'args.offset_y = {y1}')
print(f'args.width = {x2-x1}')
print(f'args.height = {y2-y1}')
# Out:
# args.offset_x = 1028
# args.offset_y = 562
# args.width = 0
# args.height = 0

# %%
pyautogui.moveTo(1537, 795)

# %% [markdown]
# ### hyperparameter

# %%
parser = argparse.ArgumentParser()
# parser.add_argument('-n', type=int)
args = parser.parse_args("")

# driver(selenium)
args.user_agent = ""  # https://www.whatismybrowser.com/detect/what-is-my-user-agent/

# record(ffmpeg)
args.duration = "00:00:10"
args.file_name = "483"

winsize = pyautogui.size()
# 노트북
if winsize == (1920, 1080):
    args.from_x = 1538
    args.from_y = 796
    args.offset_x = 1118
    args.offset_y = 560
    args.width = 774
    args.height = 440
    print("노트북")
# 학교
elif winsize == (3440, 1440):
    args.from_x = 2908
    args.from_y = 1074
    args.offset_x = 2582
    args.offset_y = 892
    args.width = 824
    args.height = 458
    print("학교")
args.show_mouse = False
args.show_region = True
# Out:
# 노트북

# %% [markdown]
# ### 12 Ways to hide your Bot Automation from Detection | How to make Selenium undetectable and stealth
# https://piprogramming.org/articles/How-to-make-Selenium-undetectable-and-stealth--7-Ways-to-hide-your-Bot-Automation-from-Detection-0000000017.html

# %%
options = Options()

# Preventing Detection
options.add_argument('user-agent=' + args.user_agent) #지정한 user-agent로 설정합니다.
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument(f"--window-position={args.offset_x},{args.offset_y}")
options.add_argument(f"--window-size={args.width},{args.height}")

# %%
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(3)
driver.get("https://code.plus/user/login")

# %% [markdown]
# ### 업로드 할 때는 꼭 지우기

# %%
driver.find_element(By.XPATH, '//*[@id="wrapper"]/section/div/div/div/form/fieldset/label[1]/input').send_keys("")
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys("")
driver.find_element(By.XPATH, '/*[@id="wrapper"]/section/div/div/div/form/fieldset/button').click()

# %% [markdown]
# ### [manualy]로그인하기

# %%
driver.get(f"https://code.plus/lecture/{args.file_name}")

# %% [markdown]
# https://blog.hashscraper.com/everything-about-solving-iframe-crawling-issues/

# %%
driver.switch_to.frame(0)

# %%
# print(driver.page_source)

# %%
driver.find_element(By.ID, 'pip-control-bar-button').click()
time.sleep(2)

# %% [markdown]
# ### resize picture-to-picture

# %%
pyautogui.moveTo(args.from_x, args.from_y, duration=0.5)
pyautogui.dragTo(args.offset_x, args.offset_y, duration=0.5)

# %% [markdown]
# ### redefine duration and filename

# %%
progressbar = driver.find_element(By.XPATH, '//*[@id="player"]/div[7]/div[8]/div[2]/div/div[1]/div/div[1]')
t = progressbar.get_attribute('aria-valuetext')
s = progressbar.get_attribute('aria-valuenow')
s
# Out:
# '157'

# %%
t = t.split('of')[-1].strip()
args.duration = t
args.duration
# Out:
# '06:39'

# %%
driver.find_element(By.XPATH, '//*[@id="player"]/div[7]/div[8]/div[1]/button').click()
cmd = f'ffmpeg -y -f dshow -t {args.duration} -i audio="virtual-audio-capturer" -rtbufsize 100M -f gdigrab -t {args.duration} -framerate 30 -offset_x {args.offset_x} -offset_y {args.offset_y} -s {args.width}x{args.height} -show_region {int(args.show_region)} -probesize 10M -draw_mouse {int(args.show_mouse)} -i desktop -c:v libx264 -r 30 -preset veryfast -tune zerolatency -crf 25 -pix_fmt yuv420p {args.file_name}.mp4' 
print(cmd)
call(cmd)
# Out:
# ffmpeg -y -f dshow -t 06:39 -i audio="virtual-audio-capturer" -rtbufsize 100M -f gdigrab -t 06:39 -framerate 30 -offset_x 1118 -offset_y 560 -s 774x440 -show_region 1 -probesize 10M -draw_mouse 0 -i desktop -c:v libx264 -r 30 -preset veryfast -tune zerolatency -crf 25 -pix_fmt yuv420p 483.mp4

# %%
driver.quit()
